# %%
import pandas as pd
import gdown

from typing import List, Dict
from tqdm.notebook import tqdm
import numpy as np
import matplotlib.pyplot as plt

# %%
google_path = 'https://drive.google.com/uc?id='
file_id = '1tqZpPvvyluyu7VVvk99tKpJd4cIkS4yi'
output_name = 'IMDB_Dataset.csv'
gdown.download(google_path+file_id,output_name,quiet=False,resume=True)
# Out:
# Downloading...
# From: https://drive.google.com/uc?id=1tqZpPvvyluyu7VVvk99tKpJd4cIkS4yi
# To: /Users/malikchettih/Projects/Emiasd-Projects/Emiasd-NLP/notebooks/IMDB_Dataset.csv
# 100%|██████████| 66.2M/66.2M [00:03<00:00, 17.9MB/s]
# 'IMDB_Dataset.csv'

# %% [markdown]
# # Introduction : Machine learning for NLP
#
# 🚧 **Question** 🚧
#
# Why would one need NLP?

# %% [markdown]
# 🚧 **Question** 🚧
#
# Can you give two main domain of NLP applications?

# %% [markdown]
# ### First application: text classification
#
# - Goal of text classification: assign a label to a text.
# - We actually want to model $p(y | x)$ where $x$ is the text and $y$ is the label.
# - Let's call $\hat{p}$ our model. $\hat{p}$ is a function that takes a text as input and outputs a label.
#
# 🚧 **Question** 🚧
#
# How would you model $\hat{p}$?

# %% [markdown]
# # From Raw data to dataset
# First take a look at the data !

# %%
df = pd.read_csv(output_name, nrows=5000)
# Print some data. Make sure all text is printed with pandas, with word wrap
pd.set_option("display.max_colwidth", None)
df.head()
# Out:
#                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                               review  \
# 0  One of the other reviewers has mentioned that after watching just 1 Oz episode you'll be hooked. They are right, as this is exactly what happened with me.<br /><br />The first thing that struck me about Oz was its brutality and unflinching scenes of violence, which set in right from the word GO. Trust me, this is not a show for the faint hearted or timid. This show pulls no punches with regards to drugs, sex or violence. Its is hardcore, in the classic use of the word.<br /><br />It is called OZ as that is the nickname given to the Oswald Maximum Security State Penitentary. It focuses mainly on Emerald City, an experimental section of the prison where all the cells have glass fronts and face inwards, so privacy is not high on the agenda. Em City is home to many..Aryans, Muslims, gangstas, Latinos, Christians, Italians, Irish and more....so scuffles, death stares, dodgy dealings and shady agreements are never far away.<br /><br />I would say the main appeal of the show is due to the fact that it goes where other shows wouldn't dare. Forget pretty pictures painted for mainstream audiences, forget charm, forget romance...OZ doesn't mess around. The first episode I ever saw struck me as so nasty it was surreal, I couldn't say I was ready for it, but as I watched more, I developed a taste for Oz, and got accustomed to the high levels of graphic violence. Not just violence, but injustice (crooked guards who'll be sold out for a nickel, inmates who'll kill on order and get away with it, well mannered, middle class inmates being turned into prison bitches due to their lack of street skills or prison experience) Watching Oz, you may become comfortable with what is uncomfortable viewing....thats if you can get in touch with your darker side.
# 1                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                             A wonderful little production. <br /><br />The filming technique is very unassuming- very old-time-BBC fashion and gives a comforting, and sometimes discomforting, sense of realism to the entire piece. <br /><br />The actors are extremely well chosen- Michael Sheen not only "has got all the polari" but he has all the voices down pat too! You can truly see the seamless editing guided by the references to Williams' diary entries, not only is it well worth the watching but it is a terrificly written and performed piece. A masterful production about one of the great master's of comedy and his life. <br /><br />The realism really comes home with the little things: the fantasy of the guard which, rather than use the traditional 'dream' techniques remains solid then disappears. It plays on our knowledge and our senses, particularly with the scenes concerning Orton and Halliwell and the sets (particularly of their flat with Halliwell's murals decorating every surface) are terribly well done.
# 2                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                     I thought this was a wonderful way to spend time on a too hot summer weekend, sitting in the air conditioned theater and watching a light-hearted comedy. The plot is simplistic, but the dialogue is witty and the characters are likable (even the well bread suspected serial killer). While some may be disappointed when they realize this is not Match Point 2: Risk Addiction, I thought it was proof that Woody Allen is still fully in control of the style many of us have grown to love.<br /><br />This was the most I'd laughed at one of Woody's comedies in years (dare I say a decade?). While I've never been impressed with Scarlet Johanson, in this she managed to tone down her "sexy" image and jumped right into a average, but spirited young woman.<br /><br />This may not be the crown jewel of his career, but it was wittier than "Devil Wears Prada" and more interesting than "Superman" a great comedy to go see with friends.
# 3                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                       Basically there's a family where a little boy (Jake) thinks there's a zombie in his closet & his parents are fighting all the time.<br /><br />This movie is slower than a soap opera... and suddenly, Jake decides to become Rambo and kill the zombie.<br /><br />OK, first of all when you're going to make a film you must Decide if its a thriller or a drama! As a drama the movie is watchable. Parents are divorcing & arguing like in real life. And then we have Jake with his closet which totally ruins all the film! I expected to see a BOOGEYMAN similar movie, and instead i watched a drama with some meaningless thriller spots.<br /><br />3 out of 10 just for the well playing parents & descent dialogs. As for the shots with Jake: just ignore them.
# 4                                                                                                                                                                                                                                                                                                                                                                                                                                                              Petter Mattei's "Love in the Time of Money" is a visually stunning film to watch. Mr. Mattei offers us a vivid portrait about human relations. This is a movie that seems to be telling us what money, power and success do to people in the different situations we encounter. <br /><br />This being a variation on the Arthur Schnitzler's play about the same theme, the director transfers the action to the present time New York where all these different characters meet and connect. Each one is connected in one way, or another to the next person, but no one seems to know the previous point of contact. Stylishly, the film has a sophisticated luxurious look. We are taken to see how these people live and the world they live in their own habitat.<br /><br />The only thing one gets out of all these souls in the picture is the different stages of loneliness each one inhabits. A big city is not exactly the best place in which human relations find sincere fulfillment, as one discerns is the case with most of the people we encounter.<br /><br />The acting is good under Mr. Mattei's direction. Steve Buscemi, Rosario Dawson, Carol Kane, Michael Imperioli, Adrian Grenier, and the rest of the talented cast, make these characters come alive.<br /><br />We wish Mr. Mattei good luck and await anxiously for his next work.
#
#   sentiment
# 0  positive
# 1  positive
# 2  positive
# 3  negative
# 4  positive

# %% [markdown]
# We need input and output: $X$ and $y$.

# %%
X = df["review"]
y = (df["sentiment"] == "positive").astype(int)

# %% [markdown]
# ## Split train and test (and validation)
#
# 🚧 **Question** 🚧
#
# It is important to do it before the preprocessing. Why now ?

# %%
from sklearn.model_selection import train_test_split



X_train, X_test, y_train, y_test = train_test_split(
    X, y, test_size=0.3, random_state=1234
)
X_train = X_train.reset_index(drop=True)
X_test = X_test.reset_index(drop=True)
y_train = y_train.reset_index(drop=True)
y_test = y_test.reset_index(drop=True)

# %%
# Explore a couple of input texts
n=2
selection = np.random.choice(len(X_train),n)
for i in  selection:
    print(X_train[i]+"\n")
# Out:
# I now that these days, some people wan't see a movie without movie styling, so much Dogma, Lars Von, Watchosky Brothers, are changed what we expect in a movie, perhaps, Casomai is no-one-more-Independent-non-american movie, the movie take all movies resources and language to tell us a simple history about love and marriage, but much more .. Fully of views, lectures and let you thinking ... and I'm sure, you can't fell boried any second of a long 116 minutes. I calculate that don't have a single scene longer that 3 o 2 1/2 minutes.
#
# Let me first off say that I am a believer of ghosts, and I do indeed know they exist. I have had enough experiences with them to know they are there.<br /><br />What I hate is the people who bring the Bible and Religion into all of this. People forget there is more than one "Bible", thousands of religions and beliefs, and different ways to interpret what is said in the Bible. Not everyone believes in God, and not everyone believes in stereo-typical religion. <br /><br />Religion does not make everything fact, one of the things I should mention in the Bible that many do not know is that even the most rampant Bible thumper is breaking the very rules written within....you are supposed to never wear more than one fabric at one time, slavery is OK, and you may murder your neighbor under certain circumstances. None of this, "Oh that was the Old testament, and now we have the New Testament." If the Bible is the word of God, and cannot be changed..there should be no changes, or versions. Religion is full of misinterpretations, mixed facts, and people who so blindly follow it that there, "Is no other way." The excuses these said blind followers use are either pathetic, or they themselves cannot explain the discrepancies properly, and instead use excuses handed down to them from either their Pastor or teacher. <br /><br />But anyhow, onto the review. I am a decent fan of "Ghost Hunters" and when I heard this show was coming soon, I was pretty excited and thought it had some potential. As much as I like watching "Ghost Hunters", I do not like some of their members, and I do not like the way they can dismiss a place as being haunted, yet cannot explain anything that is going on. Just because your investigation equipment does not pick it up, does not mean the camera filming the show did not. I am glad they are skeptical, but it's like they do not understand that just because you did not get anything on your recorder and film does not make the place haunted or not. If Ghosts were that easy to capture, it would be known as a fact, not a belief. It's more of a "right place at the right time" kind of thing, as well as if there is something there, what makes you think it's going to "perform" for you? This show is kind of silly. It's usually boring, and there is lots of talk, lots of psychics, yet hardly anything happens. The main guy's filtered narration is usually either boring to listen to, or is basically not needed.<br /><br />Also, the reliance on psychics is too abundant, as I believe VERY few of them are actually gifted. Silvia Brown is one I definitely believe in, but most are sometimes hard to believe.<br /><br />I really wanted to like this show, but of the few I have seen I have yet to be terribly impressed.

# %% [markdown]
# 🚧 **Question** 🚧
#
# Is it what we want  ?

# %% [markdown]
# ## Pre-processing and Tokenization
#
# Tokenizing a text means splitting it into words.
#
# This is not as easy as it seems. For instance, how would you tokenize the following text?
#
# ```
# I'm a student. Are you a student? Alex's course has already started!
# ```
# - We can naively split on spaces.
# - We can use a library like `nltk`, that incorporates more rules to split the text (`spacy`, `beautiful soup`)
# - We can include some *pre-processing*.
# - Deal with encoding issues.

# %%
import unicodedata
import re

# %%
def preprocess_text(text: str) -> str:
    # lower case
    text = text.lower()
    # string normalization.
    text = unicodedata.normalize("NFD", text).encode("ascii", "ignore").decode()

    # replace remove html stuffs.
    text = re.sub("<.*?>", " ", text)

    # remove non alpha numeric character, e.g punctuations ! 
    text = re.sub("[^a-z0-9]", " ", text)

    # replace numbers by the <NUM> token.
    text = re.sub(r"\d+", " ", text)

    # remove double whitespaces.
    text = re.sub(" +", " ", text.strip())
    return text

# %%
noisy_text = "Ï   lîved  in    San-Françisco...  ! for <bf>12 years</bf>."
preprocess_text(noisy_text)
# Out:
# 'i lived in san francisco for years'

# %%
X_train = X_train.apply(preprocess_text)
X_test = X_test.apply(preprocess_text)

for i in  selection:
    print(X_train[i]+"\n")
# Out:
# i now that these days some people wan t see a movie without movie styling so much dogma lars von watchosky brothers are changed what we expect in a movie perhaps casomai is no one more independent non american movie the movie take all movies resources and language to tell us a simple history about love and marriage but much more fully of views lectures and let you thinking and i m sure you can t fell boried any second of a long minutes i calculate that don t have a single scene longer that o minutes
#
# let me first off say that i am a believer of ghosts and i do indeed know they exist i have had enough experiences with them to know they are there what i hate is the people who bring the bible and religion into all of this people forget there is more than one bible thousands of religions and beliefs and different ways to interpret what is said in the bible not everyone believes in god and not everyone believes in stereo typical religion religion does not make everything fact one of the things i should mention in the bible that many do not know is that even the most rampant bible thumper is breaking the very rules written within you are supposed to never wear more than one fabric at one time slavery is ok and you may murder your neighbor under certain circumstances none of this oh that was the old testament and now we have the new testament if the bible is the word of god and cannot be changed there should be no changes or versions religion is full of misinterpretations mixed facts and people who so blindly follow it that there is no other way the excuses these said blind followers use are either pathetic or they themselves cannot explain the discrepancies properly and instead use excuses handed down to them from either their pastor or teacher but anyhow onto the review i am a decent fan of ghost hunters and when i heard this show was coming soon i was pretty excited and thought it had some potential as much as i like watching ghost hunters i do not like some of their members and i do not like the way they can dismiss a place as being haunted yet cannot explain anything that is going on just because your investigation equipment does not pick it up does not mean the camera filming the show did not i am glad they are skeptical but it s like they do not understand that just because you did not get anything on your recorder and film does not make the place haunted or not if ghosts were that easy to capture it would be known as a fact not a belief it s more of a right place at the right time kind of thing as well as if there is something there what makes you think it s going to perform for you this show is kind of silly it s usually boring and there is lots of talk lots of psychics yet hardly anything happens the main guy s filtered narration is usually either boring to listen to or is basically not needed also the reliance on psychics is too abundant as i believe very few of them are actually gifted silvia brown is one i definitely believe in but most are sometimes hard to believe i really wanted to like this show but of the few i have seen i have yet to be terribly impressed

# %% [markdown]
# **And the tokenizer ?**

# %% [markdown]
# 🚧 **Question** 🚧
#
# How to do a simple "White Space" tokenizer ?

# %%
# Try simple code 
# Test it on sample sentences. 

testsentence="I'm a student. Are you a student? Alex's course has already started!"
preprocess_text(testsentence).split(" ")
# Out:
# ['i',
#  'm',
#  'a',
#  'student',
#  'are',
#  'you',
#  'a',
#  'student',
#  'alex',
#  's',
#  'course',
#  'has',
#  'already',
#  'started']

# %% [markdown]
# In a more useful way, a tokenizer should be able to:
# - tokenize string
# - build a vocabulary
# - maybe keep track of word frequencies
# - build a natural text from its tokenized version.

# %%
import nltk
nltk.download("punkt_tab")
# Out:
# [nltk_data] Downloading package punkt_tab to
# [nltk_data]     /Users/malikchettih/nltk_data...
# [nltk_data]   Unzipping tokenizers/punkt_tab.zip.
# True

# %%
from nltk import word_tokenize

class WhiteSpaceTokenizer:
    def __init__(self):
        # The vocabulary will store the mapping between text tokens and their id.
        self.vocab = {}
        self.id_to_token = {}

        # We will keep track of the number of times a word appears in the corpus.
        self.frequencies = {}

    def split_text(self, text: str) -> List[str]:
        """Converts the text to a list of tokens (substrings)."""
        return word_tokenize(text)

    def encode(self, text: str) -> List[int]:
        """Take a text as input and return its associated tokenization, as a list of ids."""
        list_tokens = self.split_text(text)
        list_ids = []
        for token in list_tokens:
            list_ids.append(self.vocab.get(token, -1))
        return list_ids

    def decode(self, ids: List[int]) -> str:
        tokens = [self.id_to_token[i] for i in ids]
        return " ".join(tokens)

    def fit(self, corpus: List[str]):
        """Fits the tokenizer to a list of texts to construct its vocabulary."""
        current_id = 0
        for text in corpus:
            list_tokens = self.split_text(text)
            for token in list_tokens:
                token_id = self.vocab.get(token, None)
                if token_id is None:
                    self.vocab[token] = current_id
                    self.id_to_token[current_id] = token
                    self.frequencies[current_id] = 0
                    token_id = current_id
                    current_id += 1

                self.frequencies[token_id] += 1
        self.num_words = current_id
        self.vocab["<UNK>"] = -1
        self.id_to_token[-1] = "<UNK>"
        print(f"Built a vocabulary of {self.num_words} words.")

# %%
tokenizer = WhiteSpaceTokenizer()
tokenizer.fit(X_train)
# Out:
# Built a vocabulary of 32830 words.

# %%
tokenizer.vocab
# Out:
# {'i': 0,
#  'mean': 1,
#  'really': 2,
#  'this': 3,
#  'is': 4,
#  'not': 5,
#  'going': 6,
#  'to': 7,
#  'help': 8,
#  'the': 9,
#  'australian': 10,
#  'film': 11,
#  'industry': 12,
#  'make': 13,
#  'kind': 14,
#  'of': 15,
#  'with': 16,
#  'no': 17,
#  'values': 18,
#  'any': 19,
#  'okay': 20,
#  'if': 21,
#  'you': 22,
#  're': 23,
#  'a': 24,
#  'stoner': 25,
#  'and': 26,
#  'have': 27,
#  'nothing': 28,
#  'better': 29,
#  'do': 30,
#  'then': 31,
#  'maybe': 32,
#  'think': 33,
#  'makers': 34,
#  'from': 35,
#  'here': 36,
#  'should': 37,
#  'try': 38,
#  'show': 39,
#  'rest': 40,
#  'world': 41,
#  'what': 42,
#  'great': 43,
#  'talented': 44,
#  'people': 45,
#  'we': 46,
#  'vehicle': 47,
#  'for': 48,
#  'it': 49,
#  'come': 50,
#  'on': 51,
#  'now': 52,
#  'just': 53,
#  'tacky': 54,
#  'll': 55,
#  'give': 56,
#  'writer': 57,
#  'director': 58,
#  'william': 59,
#  'gove': 60,
#  'credit': 61,
#  'finding': 62,
#  'someone': 63,
#  'finance': 64,
#  'ill': 65,
#  'conceived': 66,
#  'thriller': 67,
#  'good': 68,
#  'argument': 69,
#  'wasting': 70,
#  'money': 71,
#  'subscribing': 72,
#  'hbo': 73,
#  'let': 74,
#  'alone': 75,
#  'buying': 76,
#  'dvds': 77,
#  'based': 78,
#  'cover': 79,
#  'art': 80,
#  'blurbs': 81,
#  'pedestrian': 82,
#  'dennis': 83,
#  'hopper': 84,
#  'game': 85,
#  'richard': 86,
#  'grieco': 87,
#  'add': 88,
#  'significant': 89,
#  'their': 90,
#  'resumes': 91,
#  'although': 92,
#  'direction': 93,
#  'half': 94,
#  'bad': 95,
#  'dialogue': 96,
#  'will': 97,
#  'leave': 98,
#  'grimacing': 99,
#  'wonder': 100,
#  'at': 101,
#  'its': 102,
#  'conceit': 103,
#  'storytelling': 104,
#  'worst': 105,
#  'tension': 106,
#  'suspense': 107,
#  'dread': 108,
#  'fear': 109,
#  'empathy': 110,
#  'catharsis': 111,
#  'few': 112,
#  'attractive': 113,
#  'often': 114,
#  'nude': 115,
#  'females': 116,
#  'spice': 117,
#  'up': 118,
#  'boredom': 119,
#  'but': 120,
#  'definitely': 121,
#  'best': 122,
#  'seen': 123,
#  'as': 124,
#  'trailer': 125,
#  'feel': 126,
#  'sorry': 127,
#  'guy': 128,
#  'who': 129,
#  'greenlighted': 130,
#  'thing': 131,
#  'late': 132,
#  'night': 133,
#  'zoned': 134,
#  'out': 135,
#  'viewing': 136,
#  'only': 137,
#  'been': 138,
#  'warned': 139,
#  'joseph': 140,
#  'brady': 141,
#  'clarence': 142,
#  'doolittle': 143,
#  'are': 144,
#  'two': 145,
#  'sailors': 146,
#  'four': 147,
#  'day': 148,
#  'shore': 149,
#  'in': 150,
#  'hollywood': 151,
#  'joe': 152,
#  'knows': 153,
#  'everything': 154,
#  'about': 155,
#  'girls': 156,
#  'can': 157,
#  't': 158,
#  'wait': 159,
#  'see': 160,
#  'lola': 161,
#  'while': 162,
#  'shyer': 163,
#  'needs': 164,
#  'some': 165,
#  'advice': 166,
#  'his': 167,
#  'buddy': 168,
#  'how': 169,
#  'meet': 170,
#  'they': 171,
#  'run': 172,
#  'into': 173,
#  'little': 174,
#  'boy': 175,
#  'donald': 176,
#  'martin': 177,
#  'has': 178,
#  'ran': 179,
#  'away': 180,
#  'order': 181,
#  'join': 182,
#  'navy': 183,
#  'take': 184,
#  'him': 185,
#  'home': 186,
#  'beautiful': 187,
#  'aunt': 188,
#  'susan': 189,
#  'wants': 190,
#  'be': 191,
#  'singer': 192,
#  'susie': 193,
#  'girl': 194,
#  'shyness': 195,
#  'gets': 196,
#  'way': 197,
#  'he': 198,
#  'doesn': 199,
#  'shy': 200,
#  'waitress': 201,
#  'comes': 202,
#  'brooklyn': 203,
#  'like': 204,
#  'does': 205,
#  'soon': 206,
#  'notices': 207,
#  's': 208,
#  'love': 209,
#  'boys': 210,
#  'fix': 211,
#  'when': 212,
#  'lie': 213,
#  'meeting': 214,
#  'big': 215,
#  'time': 216,
#  'music': 217,
#  'producer': 218,
#  'don': 219,
#  'even': 220,
#  'know': 221,
#  'feelings': 222,
#  'george': 223,
#  'sidney': 224,
#  'anchors': 225,
#  'aweigh': 226,
#  'musical': 227,
#  'comedy': 228,
#  'gene': 229,
#  'kelly': 230,
#  'top': 231,
#  'notch': 232,
#  'once': 233,
#  'again': 234,
#  'singing': 235,
#  'dancing': 236,
#  'routines': 237,
#  'frank': 238,
#  'sinatra': 239,
#  'terrific': 240,
#  'isn': 241,
#  'first': 242,
#  'that': 243,
#  'mind': 244,
#  'plays': 245,
#  'part': 246,
#  'well': 247,
#  'kathryn': 248,
#  'grayson': 249,
#  'fantastic': 250,
#  'abbott': 251,
#  'sadly': 252,
#  'lost': 253,
#  'gifted': 254,
#  'actress': 255,
#  'operatic': 256,
#  'soprano': 257,
#  'last': 258,
#  'month': 259,
#  'age': 260,
#  'year': 261,
#  'old': 262,
#  'dean': 263,
#  'stockwell': 264,
#  'amazing': 265,
#  'job': 266,
#  'fellow': 267,
#  'wanting': 268,
#  'become': 269,
#  'sailor': 270,
#  'jose': 271,
#  'iturbi': 272,
#  'performing': 273,
#  'himself': 274,
#  'magic': 275,
#  'piano': 276,
#  'edgar': 277,
#  'kennedy': 278,
#  'chief': 279,
#  'police': 280,
#  'station': 281,
#  'sara': 282,
#  'berner': 283,
#  'voice': 284,
#  'jerry': 285,
#  'mouse': 286,
#  'there': 287,
#  'lot': 288,
#  'stuff': 289,
#  'movie': 290,
#  'numbers': 291,
#  'look': 292,
#  'hate': 293,
#  'so': 294,
#  'energetic': 295,
#  'knew': 296,
#  'quite': 297,
#  'funny': 298,
#  'nice': 299,
#  'moment': 300,
#  'sings': 301,
#  'brahms': 302,
#  'lullaby': 303,
#  'lovely': 304,
#  'listen': 305,
#  'tango': 306,
#  'jealousy': 307,
#  'most': 308,
#  'memorable': 309,
#  'sequence': 310,
#  'one': 311,
#  'takes': 312,
#  'animated': 313,
#  'fantasy': 314,
#  'dances': 315,
#  'also': 316,
#  'tom': 317,
#  'cat': 318,
#  'butler': 319,
#  'originally': 320,
#  'asked': 321,
#  'mickey': 322,
#  'refused': 323,
#  'was': 324,
#  'nominated': 325,
#  'five': 326,
#  'oscars': 327,
#  'georgie': 328,
#  'stoll': 329,
#  'got': 330,
#  'original': 331,
#  'score': 332,
#  'high': 333,
#  'class': 334,
#  'entertainment': 335,
#  'trouble': 336,
#  'your': 337,
#  'watching': 338,
#  'numerous': 339,
#  'alternate': 340,
#  'titles': 341,
#  'generally': 342,
#  'means': 343,
#  'tried': 344,
#  'retried': 345,
#  'hide': 346,
#  'turkey': 347,
#  'various': 348,
#  'markets': 349,
#  'such': 350,
#  'brain': 351,
#  'machine': 352,
#  'which': 353,
#  'seven': 354,
#  'different': 355,
#  'super': 356,
#  'secret': 357,
#  'government': 358,
#  'project': 359,
#  'suppose': 360,
#  'able': 361,
#  'use': 362,
#  'computer': 363,
#  'read': 364,
#  'instead': 365,
#  'drives': 366,
#  'kill': 367,
#  'each': 368,
#  'other': 369,
#  'or': 370,
#  'themselves': 371,
#  'something': 372,
#  'filled': 373,
#  'b': 374,
#  'level': 375,
#  'tv': 376,
#  'actors': 377,
#  'sitting': 378,
#  'paneled': 379,
#  'room': 380,
#  'lawn': 381,
#  'chairs': 382,
#  'trying': 383,
#  'act': 384,
#  'script': 385,
#  'makes': 386,
#  'almost': 387,
#  'sense': 388,
#  'untastey': 389,
#  'avoid': 390,
#  'by': 391,
#  'far': 392,
#  'absolute': 393,
#  'years': 394,
#  'saw': 395,
#  'michael': 396,
#  'madsen': 397,
#  'figured': 398,
#  'couldn': 399,
#  'too': 400,
#  'since': 401,
#  'pretty': 402,
#  'decent': 403,
#  'films': 404,
#  'fair': 405,
#  'actor': 406,
#  'wrong': 407,
#  'waste': 408,
#  'fast': 409,
#  'forwarded': 410,
#  'through': 411,
#  'percent': 412,
#  'missed': 413,
#  'watch': 414,
#  'bond': 415,
#  'octopussy': 416,
#  'still': 417,
#  'enjoy': 418,
#  'accept': 419,
#  'production': 420,
#  'aren': 421,
#  'much': 422,
#  'above': 423,
#  'sean': 424,
#  'connery': 425,
#  'wrinkles': 426,
#  'forehead': 427,
#  'beneath': 428,
#  'an': 429,
#  'obvious': 430,
#  'toupee': 431,
#  'james': 432,
#  'get': 433,
#  'past': 434,
#  'inexperienced': 435,
#  'basinger': 436,
#  'weaker': 437,
#  'largo': 438,
#  'jolly': 439,
#  'q': 440,
#  'learn': 441,
#  'idiosyncratic': 442,
#  'barry': 443,
#  'believe': 444,
#  'hyperbolic': 445,
#  'reviews': 446,
#  'greeted': 447,
#  'release': 448,
#  'poker': 449,
#  'battle': 450,
#  'video': 451,
#  'face': 452,
#  'off': 453,
#  'them': 454,
#  'both': 455,
#  'same': 456,
#  'yours': 457,
#  'never': 458,
#  'say': 459,
#  'more': 460,
#  'probably': 461,
#  'my': 462,
#  'son': 463,
#  'yes': 464,
#  'howling': 465,
#  'classic': 466,
#  'rather': 467,
#  'werewolf': 468,
#  'admit': 469,
#  'started': 470,
#  'slowly': 471,
#  'gained': 472,
#  'momentum': 473,
#  'along': 474,
#  'finish': 475,
#  'anchorwoman': 476,
#  'changed': 477,
#  'cute': 478,
#  'gunned': 479,
#  'down': 480,
#  'camera': 481,
#  'made': 482,
#  'entertaining': 483,
#  'horror': 484,
#  'sure': 485,
#  'forget': 486,
#  'all': 487,
#  'oh': 488,
#  'anchor': 489,
#  'woman': 490,
#  'her': 491,
#  'brother': 492,
#  'find': 493,
#  'why': 494,
#  'things': 495,
#  'went': 496,
#  'did': 497,
#  'go': 498,
#  'cozy': 499,
#  'retreat': 500,
#  'transylvania': 501,
#  'somewhere': 502,
#  'where': 503,
#  'must': 504,
#  'evil': 505,
#  'magician': 506,
#  'werewolves': 507,
#  'christopher': 508,
#  'lee': 509,
#  'doing': 510,
#  'however': 511,
#  'trivia': 512,
#  'says': 513,
#  'had': 514,
#  'before': 515,
#  'role': 516,
#  'could': 517,
#  'gotten': 518,
#  'american': 519,
#  'london': 520,
#  'hell': 521,
#  'possible': 522,
#  'set': 523,
#  'after': 524,
#  'heck': 525,
#  'seem': 526,
#  'figure': 527,
#  'except': 528,
#  'bizarre': 529,
#  'prolonged': 530,
#  'sex': 531,
#  'scene': 532,
#  'fact': 533,
#  'death': 534,
#  'me': 535,
#  'gal': 536,
#  'talking': 537,
#  'loudly': 538,
#  'dude': 539,
#  'ear': 540,
#  'bleeding': 541,
#  'may': 542,
#  'am': 543,
#  'harsh': 544,
#  'absolutely': 545,
#  'stunned': 546,
#  'enough': 547,
#  'ask': 548,
#  'greatly': 549,
#  'exaggerated': 550,
#  'silly': 551,
#  'despite': 552,
#  'creepy': 553,
#  'scenes': 554,
#  'seriously': 555,
#  'ass': 556,
#  'stupid': 557,
#  'story': 558,
#  'actually': 559,
#  'deep': 560,
#  'investigating': 561,
#  'kayako': 562,
#  'found': 563,
#  'she': 564,
#  'mother': 565,
#  'miraculously': 566,
#  'speaks': 567,
#  'english': 568,
#  'exorcist': 569,
#  'fed': 570,
#  'spirits': 571,
#  'daughter': 572,
#  'yeap': 573,
#  'ok': 574,
#  'ordinary': 575,
#  'housewife': 576,
#  'affair': 577,
#  'bloke': 578,
#  'herself': 579,
#  'dead': 580,
#  'because': 581,
#  'rage': 582,
#  'became': 583,
#  'vengeful': 584,
#  'spirit': 585,
#  'kills': 586,
#  'anyone': 587,
#  'enters': 588,
#  'house': 589,
#  'acceotable': 590,
#  'killings': 591,
#  'began': 592,
#  'stretch': 593,
#  'opportunity': 594,
#  'travel': 595,
#  'throughout': 596,
#  'tokyo': 597,
#  'victims': 598,
#  'were': 599,
#  'travelling': 600,
#  'weren': 601,
#  'struck': 602,
#  'hard': 603,
#  'ghost': 604,
#  'country': 605,
#  'without': 606,
#  'paying': 607,
#  'public': 608,
#  'transport': 609,
#  'fares': 610,
#  'wouldn': 611,
#  'being': 612,
#  'snorts': 613,
#  'crown': 614,
#  'depicted': 615,
#  'very': 616,
#  'ju': 617,
#  'grudge': 618,
#  'than': 619,
#  'trash': 620,
#  'spectre': 621,
#  'truly': 622,
#  'enjoys': 623,
#  'felt': 624,
#  'mission': 625,
#  'worse': 626,
#  'viewer': 627,
#  'coming': 628,
#  'forms': 629,
#  'large': 630,
#  'strands': 631,
#  'hair': 632,
#  'power': 633,
#  'dun': 634,
#  'liked': 635,
#  'movies': 636,
#  'depicting': 637,
#  'ghosts': 638,
#  'monsters': 639,
#  'cause': 640,
#  'overall': 641,
#  'results': 642,
#  'plain': 643,
#  'storyline': 644,
#  'less': 645,
#  'exaggeration': 646,
#  'would': 647,
#  'oppenheimer': 648,
#  'brilliant': 649,
#  'series': 650,
#  'finest': 651,
#  'offerings': 652,
#  'ever': 653,
#  'pbs': 654,
#  'david': 655,
#  'suchet': 656,
#  'particularly': 657,
#  'effective': 658,
#  'edward': 659,
#  'teller': 660,
#  'recall': 661,
#  'conception': 662,
#  'spectacularly': 663,
#  'reason': 664,
#  'rate': 665,
#  'full': 666,
#  'low': 667,
#  'budget': 668,
#  'areas': 669,
#  'actual': 670,
#  'content': 671,
#  'recollection': 672,
#  'miniseries': 673,
#  'released': 674,
#  'uk': 675,
#  'july': 676,
#  'st': 677,
#  'region': 678,
#  'pal': 679,
#  'ntsc': 680,
#  'offing': 681,
#  'universal': 682,
#  'player': 683,
#  'us': 684,
#  'right': 685,
#  'amazon': 686,
#  'http': 687,
#  'tinyurl': 688,
#  'com': 689,
#  'znyyq': 690,
#  'huzzah': 691,
#  'rating': 692,
#  'mini': 693,
#  'approached': 694,
#  'aware': 695,
#  'six': 696,
#  'months': 697,
#  'sci': 698,
#  'fi': 699,
#  'channel': 700,
#  'continued': 701,
#  'pepper': 702,
#  'shows': 703,
#  'bg': 704,
#  'ads': 705,
#  'confess': 706,
#  'growing': 707,
#  'unease': 708,
#  'learned': 709,
#  'work': 710,
#  'cinematic': 711,
#  'stood': 712,
#  'test': 713,
#  'regard': 714,
#  'battlestar': 715,
#  'galactica': 716,
#  'remember': 717,
#  'chromium': 718,
#  'warriors': 719,
#  'oscillating': 720,
#  'red': 721,
#  'light': 722,
#  'visor': 723,
#  'others': 724,
#  'fondness': 725,
#  'held': 726,
#  'special': 727,
#  'effects': 728,
#  'evolutionary': 729,
#  'many': 730,
#  'state': 731,
#  'during': 732,
#  'especially': 733,
#  'those': 734,
#  'television': 735,
#  'memories': 736,
#  'resolve': 737,
#  'around': 738,
#  'arc': 739,
#  'relationships': 740,
#  'helped': 741,
#  'overcome': 742,
#  'challenges': 743,
#  'faced': 744,
#  'frankly': 745,
#  'latter': 746,
#  'group': 747,
#  'core': 748,
#  'pulled': 749,
#  'together': 750,
#  'save': 751,
#  'another': 752,
#  'empire': 753,
#  'cylons': 754,
#  'gain': 755,
#  'extermination': 756,
#  'human': 757,
#  'race': 758,
#  'yet': 759,
#  'base': 760,
#  'stars': 761,
#  'swirling': 762,
#  'men': 763,
#  'women': 764,
#  'came': 765,
#  'enemy': 766,
#  'virtually': 767,
#  'unlimited': 768,
#  'resources': 769,
#  'somehow': 770,
#  'managed': 771,
#  'survive': 772,
#  'until': 773,
#  'next': 774,
#  'didn': 775,
#  'technology': 776,
#  'fire': 777,
#  'survived': 778,
#  'cared': 779,
#  'trusted': 780,
#  'flaws': 781,
#  'times': 782,
#  'sappy': 783,
#  'care': 784,
#  'writers': 785,
#  'current': 786,
#  'rendition': 787,
#  'seemed': 788,
#  'understand': 789,
#  'ways': 790,
#  'took': 791,
#  'least': 792,
#  'character': 793,
#  'names': 794,
#  'crafted': 795,
#  'called': 796,
#  'reinvention': 797,
#  'science': 798,
#  'fiction': 799,
#  'goal': 800,
#  'judged': 801,
#  'accomplished': 802,
#  'failure': 803,
#  'derivitive': 804,
#  'endeavors': 805,
#  'long': 806,
#  'borrows': 807,
#  'liberally': 808,
#  'tng': 809,
#  'ds': 810,
#  'babylon': 811,
#  'battlefield': 812,
#  'earth': 813,
#  'unfortunate': 814,
#  'ronald': 815,
#  'd': 816,
#  'moore': 817,
#  'contributor': 818,
#  'popular': 819,
#  'decade': 820,
#  'contribution': 821,
#  'hope': 822,
#  'difficulties': 823,
#  'appears': 824,
#  'conflict': 825,
#  'bridge': 826,
#  'crew': 827,
#  'enterprise': 828,
#  'e': 829,
#  'inviolable': 830,
#  'rule': 831,
#  'roddenberry': 832,
#  'lived': 833,
#  'under': 834,
#  'rules': 835,
#  'every': 836,
#  'break': 837,
#  'longer': 838,
#  'authority': 839,
#  'ron': 840,
#  'seems': 841,
#  'forgotten': 842,
#  'lessons': 843,
#  'acknowledged': 844,
#  'master': 845,
#  'writing': 846,
#  'created': 847,
#  'dysfuntional': 848,
#  'cast': 849,
#  'intent': 850,
#  'creating': 851,
#  'besides': 852,
#  'dysfunctional': 853,
#  'bit': 854,
#  'believable': 855,
#  'military': 856,
#  'unprovokedly': 857,
#  'striking': 858,
#  'superior': 859,
#  'officer': 860,
#  'couple': 861,
#  'days': 862,
#  'hack': 863,
#  'execution': 864,
#  'happened': 865,
#  'period': 866,
#  'war': 867,
#  'remembered': 868,
#  'earlier': 869,
#  'penned': 870,
#  'capt': 871,
#  'kirk': 872,
#  'killed': 873,
#  'alas': 874,
#  'surfing': 875,
#  'infomercials': 876,
#  'sitcoms': 877,
#  'morning': 878,
#  'expect': 879,
#  'rose': 880,
#  'mcgowan': 881,
#  'hot': 882,
#  'performance': 883,
#  'oscar': 884,
#  'worthy': 885,
#  'ups': 886,
#  'downs': 887,
#  'twists': 888,
#  'end': 889,
#  'honesty': 890,
#  'awful': 891,
#  'typical': 892,
#  'slasher': 893,
#  'gore': 894,
#  'nudity': 895,
#  'real': 896,
#  'violence': 897,
#  'acting': 898,
#  'nightkill': 899,
#  'robert': 900,
#  'mitchum': 901,
#  'weary': 902,
#  'private': 903,
#  'eye': 904,
#  'probing': 905,
#  'case': 906,
#  'missing': 907,
#  'industrialist': 908,
#  'mike': 909,
#  'connors': 910,
#  'hired': 911,
#  'jaclyn': 912,
#  'smith': 913,
#  'anxious': 914,
#  'wife': 915,
#  'man': 916,
#  'fails': 917,
#  'inform': 918,
#  'husband': 919,
#  'whereabouts': 920,
#  'lover': 921,
#  'franciscus': 922,
#  'dispose': 923,
#  'wealthy': 924,
#  'hubby': 925,
#  'rotten': 926,
#  'mannix': 927,
#  'goes': 928,
#  'western': 929,
#  'monkeys': 930,
#  'abused': 931,
#  'models': 932,
#  'lean': 933,
#  'against': 934,
#  'cars': 935,
#  'constantly': 936,
#  'upstaged': 937,
#  'sybil': 938,
#  'danning': 939,
#  'giallo': 940,
#  'style': 941,
#  'wrap': 942,
#  'brings': 943,
#  'whole': 944,
#  'mess': 945,
#  'bitter': 946,
#  'cinema': 947,
#  'sooooo': 948,
#  'poor': 949,
#  'halloween': 950,
#  'mixed': 951,
#  'trick': 952,
#  'treats': 953,
#  'rated': 954,
#  'r': 955,
#  'graphic': 956,
#  'sexual': 957,
#  'situations': 958,
#  'among': 959,
#  'flock': 960,
#  'revenge': 961,
#  'minded': 962,
#  'action': 963,
#  'flicks': 964,
#  'bill': 965,
#  'vol': 966,
#  'punisher': 967,
#  'walking': 968,
#  'tall': 969,
#  'works': 970,
#  'thanks': 971,
#  'always': 972,
#  'watchable': 973,
#  'denzel': 974,
#  'washington': 975,
#  'today': 976,
#  'j': 977,
#  'quinnell': 978,
#  'novel': 979,
#  'filmed': 980,
#  'scott': 981,
#  'glenn': 982,
#  'luck': 983,
#  'ex': 984,
#  'mercenary': 985,
#  'stooped': 986,
#  'drinking': 987,
#  'flash': 988,
#  'jack': 989,
#  'daniels': 990,
#  'partner': 991,
#  'walken': 992,
#  'offers': 993,
#  'chance': 994,
#  'redemption': 995,
#  'bodyguard': 996,
#  'dakota': 997,
#  'fanning': 998,
#  'mexican': 999,
#  ...}

# %%
tokenizer.frequencies[40]
# Out:
# 234

# %%
X_train.shape
# Out:
# (3500,)

# %%
for i in  selection:
    print(tokenizer.split_text(X_train[i]))
# Out:
# ['i', 'now', 'that', 'these', 'days', 'some', 'people', 'wan', 't', 'see', 'a', 'movie', 'without', 'movie', 'styling', 'so', 'much', 'dogma', 'lars', 'von', 'watchosky', 'brothers', 'are', 'changed', 'what', 'we', 'expect', 'in', 'a', 'movie', 'perhaps', 'casomai', 'is', 'no', 'one', 'more', 'independent', 'non', 'american', 'movie', 'the', 'movie', 'take', 'all', 'movies', 'resources', 'and', 'language', 'to', 'tell', 'us', 'a', 'simple', 'history', 'about', 'love', 'and', 'marriage', 'but', 'much', 'more', 'fully', 'of', 'views', 'lectures', 'and', 'let', 'you', 'thinking', 'and', 'i', 'm', 'sure', 'you', 'can', 't', 'fell', 'boried', 'any', 'second', 'of', 'a', 'long', 'minutes', 'i', 'calculate', 'that', 'don', 't', 'have', 'a', 'single', 'scene', 'longer', 'that', 'o', 'minutes']
# ['let', 'me', 'first', 'off', 'say', 'that', 'i', 'am', 'a', 'believer', 'of', 'ghosts', 'and', 'i', 'do', 'indeed', 'know', 'they', 'exist', 'i', 'have', 'had', 'enough', 'experiences', 'with', 'them', 'to', 'know', 'they', 'are', 'there', 'what', 'i', 'hate', 'is', 'the', 'people', 'who', 'bring', 'the', 'bible', 'and', 'religion', 'into', 'all', 'of', 'this', 'people', 'forget', 'there', 'is', 'more', 'than', 'one', 'bible', 'thousands', 'of', 'religions', 'and', 'beliefs', 'and', 'different', 'ways', 'to', 'interpret', 'what', 'is', 'said', 'in', 'the', 'bible', 'not', 'everyone', 'believes', 'in', 'god', 'and', 'not', 'everyone', 'believes', 'in', 'stereo', 'typical', 'religion', 'religion', 'does', 'not', 'make', 'everything', 'fact', 'one', 'of', 'the', 'things', 'i', 'should', 'mention', 'in', 'the', 'bible', 'that', 'many', 'do', 'not', 'know', 'is', 'that', 'even', 'the', 'most', 'rampant', 'bible', 'thumper', 'is', 'breaking', 'the', 'very', 'rules', 'written', 'within', 'you', 'are', 'supposed', 'to', 'never', 'wear', 'more', 'than', 'one', 'fabric', 'at', 'one', 'time', 'slavery', 'is', 'ok', 'and', 'you', 'may', 'murder', 'your', 'neighbor', 'under', 'certain', 'circumstances', 'none', 'of', 'this', 'oh', 'that', 'was', 'the', 'old', 'testament', 'and', 'now', 'we', 'have', 'the', 'new', 'testament', 'if', 'the', 'bible', 'is', 'the', 'word', 'of', 'god', 'and', 'can', 'not', 'be', 'changed', 'there', 'should', 'be', 'no', 'changes', 'or', 'versions', 'religion', 'is', 'full', 'of', 'misinterpretations', 'mixed', 'facts', 'and', 'people', 'who', 'so', 'blindly', 'follow', 'it', 'that', 'there', 'is', 'no', 'other', 'way', 'the', 'excuses', 'these', 'said', 'blind', 'followers', 'use', 'are', 'either', 'pathetic', 'or', 'they', 'themselves', 'can', 'not', 'explain', 'the', 'discrepancies', 'properly', 'and', 'instead', 'use', 'excuses', 'handed', 'down', 'to', 'them', 'from', 'either', 'their', 'pastor', 'or', 'teacher', 'but', 'anyhow', 'onto', 'the', 'review', 'i', 'am', 'a', 'decent', 'fan', 'of', 'ghost', 'hunters', 'and', 'when', 'i', 'heard', 'this', 'show', 'was', 'coming', 'soon', 'i', 'was', 'pretty', 'excited', 'and', 'thought', 'it', 'had', 'some', 'potential', 'as', 'much', 'as', 'i', 'like', 'watching', 'ghost', 'hunters', 'i', 'do', 'not', 'like', 'some', 'of', 'their', 'members', 'and', 'i', 'do', 'not', 'like', 'the', 'way', 'they', 'can', 'dismiss', 'a', 'place', 'as', 'being', 'haunted', 'yet', 'can', 'not', 'explain', 'anything', 'that', 'is', 'going', 'on', 'just', 'because', 'your', 'investigation', 'equipment', 'does', 'not', 'pick', 'it', 'up', 'does', 'not', 'mean', 'the', 'camera', 'filming', 'the', 'show', 'did', 'not', 'i', 'am', 'glad', 'they', 'are', 'skeptical', 'but', 'it', 's', 'like', 'they', 'do', 'not', 'understand', 'that', 'just', 'because', 'you', 'did', 'not', 'get', 'anything', 'on', 'your', 'recorder', 'and', 'film', 'does', 'not', 'make', 'the', 'place', 'haunted', 'or', 'not', 'if', 'ghosts', 'were', 'that', 'easy', 'to', 'capture', 'it', 'would', 'be', 'known', 'as', 'a', 'fact', 'not', 'a', 'belief', 'it', 's', 'more', 'of', 'a', 'right', 'place', 'at', 'the', 'right', 'time', 'kind', 'of', 'thing', 'as', 'well', 'as', 'if', 'there', 'is', 'something', 'there', 'what', 'makes', 'you', 'think', 'it', 's', 'going', 'to', 'perform', 'for', 'you', 'this', 'show', 'is', 'kind', 'of', 'silly', 'it', 's', 'usually', 'boring', 'and', 'there', 'is', 'lots', 'of', 'talk', 'lots', 'of', 'psychics', 'yet', 'hardly', 'anything', 'happens', 'the', 'main', 'guy', 's', 'filtered', 'narration', 'is', 'usually', 'either', 'boring', 'to', 'listen', 'to', 'or', 'is', 'basically', 'not', 'needed', 'also', 'the', 'reliance', 'on', 'psychics', 'is', 'too', 'abundant', 'as', 'i', 'believe', 'very', 'few', 'of', 'them', 'are', 'actually', 'gifted', 'silvia', 'brown', 'is', 'one', 'i', 'definitely', 'believe', 'in', 'but', 'most', 'are', 'sometimes', 'hard', 'to', 'believe', 'i', 'really', 'want ...

# %% [markdown]
# # Basic Text classifiers
#
# Now wa have pre-processed and tokenized text ! Let's go for classification. To allow fair and easy comparison we start by a Base class.

# %%
class BaseTextClassifier:

    def predict(self, text: str) -> int:
        raise NotImplementedError()

    def predict_dataset(self, X: List[str]) -> List[int]:
        return [self.predict(x) for x in X]

    def evaluate(self, X: List[str], y: List[int]) -> Dict[str, float]:
        predictions = self.predict_dataset(X)
        y_array = np.array(y)
        accuracy = np.mean(predictions == y_array)
        return {"accuracy": accuracy}

# %% [markdown]
# 🚧 **Question** 🚧
# Propose a a very basic classifier.
# - Gather counts of "positive" and "negative" words.
# - But how do we know if a word is positive or negative ?
# - We can look at words in the training set.

# %%
# Inherit from the Base class and implement a classifier based on counts 

class CountBasedClassifier( BaseTextClassifier ): 
    def __init__(self, n_classes):
        self.n_classes = n_classes
        self.tokenizer = WhiteSpaceTokenizer()
        self.counts = {}
        
    def fit(self, X, y): 
        self.tokenizer.fit(X)
        # X est le corpus : un ensemble de textes
        for i in range(len(X)):
            tokens = self.tokenizer.encode(X[i])
            # tokens la liste des mots (sous forme d'indices) dans le texte X[i]
            for iw in tokens: 
                if iw == -1: 
                    continue 
                key =  y[i],iw
                if key in self.counts.keys():               
                    self.counts[key] += 1 
                else :
                    self.counts[key] = 1 
                    
    def predict(self, text): 
        wordidx = self.tokenizer.encode(text)
        # scores par classe pour le text
        scores = np.zeros(self.n_classes) 
        for i in wordidx :
            if i == -1 :
                continue
            for c in range(self.n_classes): 
                key = c,i
                if key in self.counts.keys(): 
                    scores[c] += self.counts[c,i]
        return np.argmax(scores)

# %%
classif = CountBasedClassifier(2)
classif.fit(X_train, y_train)
# Out:
# Built a vocabulary of 32830 words.

# %%
classif.predict("I")
# Out:
# np.int64(0)

# %%
print("Accuracy ")
classif.evaluate(X_test, y_test)
# Out:
# Accuracy
# {'accuracy': np.float64(0.6506666666666666)}

# %%
print("Equilibre entre classe:")
y_test.sum()/len(y_test)
# Out:
# Equilibre entre classe:
# np.float64(0.49333333333333335)

# %% [markdown]
# ## Do you know the Zipf Law ?
#
# 🚧 **Question** 🚧
# The tokenizer contains the counts for every words in the training set. Plot the the word counts in descending order.
# Comment the result.

# %%
wc = list(classif.tokenizer.frequencies.values())
wc.sort(reverse=True)

# %%
plt.loglog(wc)

# %%
# Inherit from the Base class and implement a classifier based on counts 

class ProbaClassifier( BaseTextClassifier ): 
    def __init__(self, n_classes):
        self.n_classes = n_classes
        # This attribute is not used, but kept for API consistency
        self.tokenizer = WhiteSpaceTokenizer()

    def get_word_count(self, X, y):
        words_count = np.zeros((self.n_classes, self.tokenizer.num_words), dtype=int)
        for i in range(len(X)):
            tokens = self.tokenizer.encode(X[i])
            for w in tokens:
                if w != -1:
                    words_count[y[i], w] += 1
        frequencies = words_count / words_count.sum(axis=1, keepdims=True)
        return words_count, frequencies

    def fit(self, X, y):
        self.tokenizer.fit(X)
        word_count, frequencies = self.get_word_count(X, y)
        self.frequencies = frequencies
        self.words_count = word_count

    def predict(self, text: str) -> int:
        """
        Calculate a score for each label by summing
        the normalized frequencies of the words in 'text'.
        Then choose the label with the highest score.
        """
        global_count = self.words_count.sum(axis=0)
        global_freq = global_count / global_count.sum()
        words = self.tokenizer.encode(text)
        words = np.array([w for w in words if w != -1])
        words_count_per_class = self.frequencies[:, words] / global_freq[words]
        scores = words_count_per_class.sum(axis=1)
        return np.argmax(scores)

# %%
classifier = ProbaClassifier(2)
classifier.fit(X_train, y_train)
print(classifier.evaluate(X_test, y_test))
# Out:
# Built a vocabulary of 32830 words.
# {'accuracy': np.float64(0.8193333333333334)}

# %%
print(classifier.words_count.sum(axis=0))
# Out:
# [11910   232  1623 ...     1     1     1]

# %%
from nltk.corpus import stopwords
nltk.download('stopwords')
nltk.download('wordnet')
stop = set(stopwords.words('french'))
print(stop)
len(stop)
# Out:
# [nltk_data] Downloading package stopwords to
# [nltk_data]     /Users/malikchettih/nltk_data...
# [nltk_data]   Unzipping corpora/stopwords.zip.
# [nltk_data] Downloading package wordnet to
# [nltk_data]     /Users/malikchettih/nltk_data...
# {'étées', 'eusse', 'eut', 'fut', 'es', 'aurez', 'se', 'mon', 't', 'au', 'soient', 'étions', 'me', 'furent', 'n', 'sois', 'qu', 'eûtes', 'mes', 'les', 'ou', 'fût', 'fussiez', 'étés', 'eût', 'ai', 's', 'fusse', 'seraient', 'ce', 'eue', 'te', 'avez', 'qui', 'eussent', 'fussions', 'seras', 'fussent', 'elle', 'auront', 'fûmes', 'son', 'êtes', 'toi', 'm', 'on', 'mais', 'aient', 'y', 'fûtes', 'eussions', 'est', 'eux', 'en', 'eues', 'eûmes', 'le', 'serions', 'serait', 'ayez', 'la', 'moi', 'sera', 'auraient', 'avait', 'aviez', 'aura', 'eusses', 'étants', 'étais', 'ils', 'étante', 'nous', 'soyons', 'il', 'vous', 'ne', 'ta', 'tes', 'à', 'soit', 'avaient', 'aies', 'aurait', 'eurent', 'serez', 'aux', 'aurons', 'que', 'aurais', 'tu', 'ayant', 'seront', 'eussiez', 'étaient', 'ses', 'et', 'l', 'serais', 'de', 'avions', 'ton', 'du', 'suis', 'avons', 'seriez', 'ma', 'ayants', 'auras', 'notre', 'sur', 'soyez', 'ait', 'dans', 'nos', 'votre', 'serons', 'aie', 'c', 'ayons', 'sont', 'ces', 'par', 'ayantes', 'leur', 'pour', 'ont', 'étant', 'sommes', 'même', 'je', 'lui', 'étiez', 'fus', 'avais', 'j', 'une', 'pas', 'fusses', 'sa', 'd', 'ayante', 'étantes', 'eu', 'vos', 'un', 'étée', 'avec', 'été', 'aurions', 'aurai', 'auriez', 'des', 'était', 'serai', 'eus', 'as'}
# 157

# %%
from nltk.stem import WordNetLemmatizer, PorterStemmer
lem = WordNetLemmatizer()
porter = PorterStemmer()
print(lem.lemmatize("flowers"))
print(porter.stem("flowers"))
# Out:
# flower
# flower

# %% [markdown]
# ## Do you know SciKit-Learn ?
#
# 🚧 **Question** 🚧
#
# How can we optimize the algorithm?
# - For the tokenization and/or vectorization ?
# - For the classifier ? Write you count-based classifier that uses the vectorizer of SKLearn.
# -

# %%
from sklearn.feature_extraction.text import CountVectorizer
vectorizer = CountVectorizer()
Xvtrain = vectorizer.fit_transform(X_train).toarray()
Xvtest = vectorizer.transform(X_test).toarray()

# %%
print(vectorizer.vocabulary_)
# Out:
# {'mean': 18065, 'really': 23355, 'this': 29259, 'is': 15131, 'not': 19869, 'going': 12118, 'to': 29496, 'help': 13287, 'the': 29161, 'australian': 1838, 'film': 10627, 'industry': 14527, 'make': 17493, 'kind': 15949, 'of': 20142, 'with': 32206, 'no': 19757, 'values': 31023, 'any': 1216, 'okay': 20208, 'if': 14101, 'you': 32634, 're': 23307, 'stoner': 27844, 'and': 1027, 'have': 13073, 'nothing': 19883, 'better': 2705, 'do': 8269, 'then': 29184, 'maybe': 17954, 'think': 29240, 'makers': 17499, 'from': 11383, 'here': 13337, 'should': 26159, 'try': 30077, 'show': 26178, 'rest': 24087, 'world': 32344, 'what': 31915, 'great': 12380, 'talented': 28744, 'people': 21265, 'we': 31753, 'vehicle': 31107, 'for': 11058, 'it': 15173, 'come': 5504, 'on': 20253, 'now': 19922, 'just': 15663, 'tacky': 28693, 'll': 16957, 'give': 11968, 'writer': 32440, 'director': 7917, 'william': 32097, 'gove': 12236, 'credit': 6482, 'finding': 10667, 'someone': 27017, 'finance': 10657, 'ill': 14132, 'conceived': 5731, 'thriller': 29313, 'good': 12155, 'argument': 1417, 'wasting': 31691, 'money': 18806, 'subscribing': 28151, 'hbo': 13120, 'let': 16660, 'alone': 794, 'buying': 3920, 'dvds': 8815, 'based': 2278, 'cover': 6336, 'art': 1504, 'blurbs': 3071, 'pedestrian': 21193, 'dennis': 7441, 'hopper': 13739, 'game': 11598, 'richard': 24315, 'grieco': 12436, 'add': 280, 'significant': 26312, 'their': 29172, 'resumes': 24125, 'although': 830, 'direction': 7912, 'half': 12780, 'bad': 2042, 'dialogue': 7753, 'will': 32090, 'leave': 16529, 'grimacing': 12453, 'wonder': 32276, 'at': 1690, 'its': 15186, 'conceit': 5726, 'storytelling': 27886, 'worst': 32372, 'tension': 29058, 'suspense': 28474, 'dread': 8574, 'fear': 10417, 'empathy': 9290, 'catharsis': 4412, 'few': 10553, 'attractive': 1776, 'often': 20185, 'nude': 19940, 'females': 10489, 'spice': 27275, 'up': 30863, 'boredom': 3271, 'but': 3892, 'definitely': 7293, 'best': 2683, 'seen': 25621, 'as': 1538, 'trailer': 29754, 'feel': 10460, 'sorry': 27088, 'guy': 12685, 'who': 32005, 'greenlighted': 12402, 'thing': 29238, 'late': 16393, 'night': 19685, 'zoned': 32782, 'out': 20492, 'viewing': 31275, 'only': 20270, 'been': 2461, 'warned': 31644, 'joseph': 15546, 'brady': 3393, 'clarence': 5103, 'doolittle': 8399, 'are': 1402, 'two': 30210, 'sailors': 24962, 'four': 11198, 'day': 7075, 'shore': 26138, 'in': 14340, 'hollywood': 13630, 'joe': 15490, 'knows': 16070, 'everything': 9790, 'about': 75, 'girls': 11962, 'can': 4091, 'wait': 31536, 'see': 25602, 'lola': 17036, 'while': 31951, 'shyer': 26242, 'needs': 19513, 'some': 27012, 'advice': 416, 'his': 13530, 'buddy': 3709, 'how': 13834, 'meet': 18136, 'they': 29222, 'run': 24822, 'into': 14961, 'little': 16931, 'boy': 3372, 'donald': 8372, 'martin': 17796, 'has': 13013, 'ran': 23175, 'away': 1934, 'order': 20387, 'join': 15507, 'navy': 19456, 'take': 28730, 'him': 13484, 'home': 13643, 'beautiful': 2412, 'aunt': 1816, 'susan': 28459, 'wants': 31614, 'be': 2365, 'singer': 26407, 'susie': 28466, 'girl': 11955, 'shyness': 26245, 'gets': 11857, 'way': 31740, 'he': 13121, 'doesn': 8304, 'shy': 26240, 'waitress': 31540, 'comes': 5517, 'brooklyn': 3627, 'like': 16804, 'does': 8303, 'soon': 27048, 'notices': 19890, 'love': 17158, 'boys': 3381, 'fix': 10764, 'when': 31931, 'lie': 16751, 'meeting': 18138, 'big': 2759, 'time': 29417, 'music': 19202, 'producer': 22487, 'don': 8369, 'even': 9766, 'know': 16062, 'feelings': 10462, 'george': 11826, 'sidney': 26286, 'anchors': 1024, 'aweigh': 1938, 'musical': 19203, 'comedy': 5513, 'gene': 11768, 'kelly': 15831, 'top': 29601, 'notch': 19873, 'once': 20257, 'again': 501, 'singing': 26411, 'dancing': 6947, 'routines': 24722, 'frank': 11248, 'sinatra': 26392, 'terrific': 29090, 'isn': 15156, 'first': 10727, 'that': 29154, 'mind': 18481, 'plays': 21775, 'part': 20968, 'well': 31854, 'kathryn': 15772, 'grayson': 12373, 'fantastic': 10287, 'abbott': 26, 'sadly': 24932, 'lost': 17125, 'gifted': 11904, 'actress': 253, 'operatic': 20312, 'soprano ...

# %% [markdown]
# Now we have a "SKLearn" dataset,  we can also use all the classifiers we want from this library:
# - Naive Bayes
# - Logistic Regression

# %%
from sklearn.linear_model import LogisticRegression

# %%
classif = LogisticRegression(max_iter=200, tol=1e-2)
classif.fit(Xvtrain,y_train)
# Out:
# LogisticRegression(max_iter=200, tol=0.01)

# %%
y_pred = classif.predict(Xvtest)
accuracy  = np.mean(y_test==y_pred)
print(accuracy)
# Out:
# 0.8726666666666667

# %% [markdown]
# $$P(y | x ) = \frac{1}{1+\exp({w^t x})}$$
# avec :
# - x : le vecteur qui contient les comptes de mots
# - w : un vecteur de paramètre, de même taille que x
# Si $x = ( x_i )$,  $x_i$ le compte du mot i, i étant l'indice dans le vocabulaire.
# $$ w^t x = \sum_i w_i\times x_i $$
#
# Formule de Bayes
# $$P(y | x ) = \frac{P(x | y )P( y )}{P( x )}  = \frac{P(x , y )}{P( x )} $$

# %%
from sklearn.naive_bayes import MultinomialNB
classif=MultinomialNB()
classif.fit(Xvtrain,y_train)

y_pred = classif.predict(Xvtest)
accuracy  = np.mean(y_test==y_pred)
print(accuracy)
# Out:
# 0.8393333333333334

# %%
from sklearn.naive_bayes import BernoulliNB
classif=BernoulliNB()
classif.fit(Xvtrain,y_train)

y_pred = classif.predict(Xvtest)
accuracy  = np.mean(y_test==y_pred)
print(accuracy)
# Out:
# 0.848

# %%
y_pred = classif.predict(Xvtest)
accuracy  = np.mean(y_test==y_pred)
print(accuracy)
# Out:
# 0.848

# %% [markdown]
# # Vectorization and NLP
#
# In Machine Learning for supervised classification, many approaches work with vectors. The input to be classified is represented by a vector which is given to the classifier. This input vector gathers a set of numerical features that describes the input. What kind of features can we extract from text ?
# The "easy features" are what we have done:
# - Counting words (do we need all the words ?)
# - Could we use binary features ?
# - Counting n-grams (why ?)
#
#
# 🚧 **Question** 🚧
#
# For instance, take what we did for the logistic regression and provide an interpretation of the model, its decision rule and the parameters ?

# %% [markdown]
# ## Bag of words model
#
# - We count the number of times each word appears in a text.
# - We can then represent the text as a vector of counts.

# %% [markdown]
# ## Frequency-based vectorization
#
# - We can normalize the counts by the total number of words in the text.
# - This gives us the frequency of each word in the text.
# - This is called the **term frequency**.

# %% [markdown]
# ## TF-IDF
#
# - **Intuition**:
#   - If a word appears many times in a document, it is important.
#   - If a word appears in many documents, it is not very informative.
#   - For instance, the words "the", "and" appears in many documents.
#
# - **TF-IDF**:
#   - We multiply the term frequency by the inverse document frequency.
#   - Used a lot for information retrieval.

# %% [markdown]
# ### Term Frequency (TF)
# $$
# \text{TF}(t, d) = \frac{f_{t, d}}{\sum_{t' \in d} f_{t', d}}
# $$
# Where:
# - $ f_{t, d} $: Frequency of term $ t $ in document $ d $.
# - $ \sum_{t' \in d} f_{t', d} $: Total number of terms in document $ d $.
#
# ---
#
# ### Inverse Document Frequency (IDF)
# $$
# \text{IDF}(t) = \log\left(\frac{N + 1}{\text{DF}(t) + 1}\right) + 1
# $$
# Where:
# - $ N $: Total number of documents.
# - $ \text{DF}(t) $: Number of documents containing the term $ t $.
# - Adding $ +1 $ in numerator and denominator prevents division by zero.
#
# ---
#
# ### TF-IDF
# $$
# \text{TF-IDF}(t, d) = \text{TF}(t, d) \times \text{IDF}(t)
# $$
#
#
# 🚧 **Question** 🚧
#
# Write a function that computes the TF-IDF matrix from a word count matrix

# %%
def word_count_to_tfidf(word_count_matrix):
    # <-- TODO 
    return tfidf_matrix

# %% [markdown]
# ## Application: identifying similar documents
#
# - We can use TF-IDF to identify similar documents.
# - To quickly compare two documents, we can compute the cosine similarity between their TF-IDF vectors.

# %%
from sklearn.feature_extraction.text import TfidfVectorizer

vectorizer = TfidfVectorizer()
X_vec = vectorizer.fit_transform(X.apply(preprocess_text))

query = "boats planes and cars"

# %% [markdown]
# 🚧 **Question** 🚧
#
# Find the most similar text in $X$ ?

# %%
qv = vectorizer.transform([query])
similarities = X_vec.dot(qv.T)
# print(similarities.shape)
bestmatch = np.argmax(similarities)
print(bestmatch)
# Out:
# 1180

# %%
print(X[bestmatch])
# Out:
# The cars in this movie are awesome. The acting in this movie is awful. The plot and driving scenes don't make much sense and are equally bad. If you get really bothered by movies where someone shifts and suddenly goes ridiculously faster, save yourself the trouble and money. Good movie for racing fans? Well, there is a part where they make the mistake of referring to a NASCAR driver as a rally car driver. If you can't tell the difference, go watch it, you'll have a blast. It really comes down to this, there are really really really nice cars in this movie, they are driven horribly and are completely unrealistic. The acting is horrible mainly because of the extremely bad plot. If you want to see hot girls, turn on mtv or vh1 instead. I am disappointed that such nice cars would be represented in such a bad movie. If the class of the cars were to match that of the movie, they should be racing with rusted bicycles.

# %% [markdown]
# ## Limitations of frequency-based vectorization
#
# - Each word is treated independently, regardless of its context.
# - The order of words is not taken into account.
# - Semantic information is not captured.
# - And other ideas of limitations ?

# %% [markdown]
# # Word embeddings
#
# **A Intuitive example**: Suppose we are interested in classifying texts in 4 categories: "World", "Sports", "Business", "Sci/Tech".

# %% [markdown]
# ## Word embeddings
# - We could manually design a vector for each word.
# - For instance, over the dimensions [World, Sported, Business, Sci/Tech]:
#   - "Football" could be [0, 0.2, 0.8, 0]
#   - "Microsoft" could be [0, 0, 0.5, 0.5]
#   - "Olympics" could be [0.25, 0.75, 0, 0]
# - But doing this naively would be very inefficient.
#   - Hard to design the vectors.
#   - Hard to compute them
#   - Does not account for the context of the words.

# %% [markdown]
# ## Learning word embeddings
#
# - Instead, we can learn those embeddings from the data!
# - Same idea than with neural networks: we learn the weights of the embeddings from the data.
#
# **In practice**
# - Set a dimension $d$ for the embeddings (e.g. 100).
# - For each word, initialize a random vector of size $d$.
# - Train a model to predict something from the embeddings.
#
#
#
#
# 🚧 **Question** 🚧
#
# Add the necessary code in the following class.

# %%
from torch import nn
import torch
import torch.nn as nn 
emb = nn.Embedding(20, 2)  # Création d'un module, avec initialisation aléatoire
txt = [ 1, 0, 6,18, 1]
txt = torch.LongTensor(txt)
print(txt)
emb(txt)
# Out:
# tensor([ 1,  0,  6, 18,  1])
# tensor([[ 0.8902,  0.8363],
#         [ 0.5198, -0.0907],
#         [ 3.5193, -0.0675],
#         [ 1.3135,  1.2319],
#         [ 0.8902,  0.8363]], grad_fn=<EmbeddingBackward0>)

# %%
class WordEmbeddingClassifier(BaseTextClassifier):
    def __init__(self, n_classes=2, voc_size, d_embed, tokenizer, lr=1e-3, n_epochs=10):
        self.tokenizer = tokenizer
        self.voc_size = voc_size
        self.lr = lr
        self.d_embed = d_embed
        self.n_epochs = n_epochs
        self.n_classes = n_classes
        self.embeddings = nn.Embedding(voc_size, d_embed)
        
    def fit(self, X, y):
        # un text = une liste ou un tableau de d'indices 
        # Tokenizer appliqué sur X (les données d'apprentissage): 
        # X est une liste de Tensor 
        torch.optim.Adam(  , self.lr )
        lossf = torch.nn.NLLLoss() # <-
        for e in range(self.n_epochs): 
            

            
    def predict(self, text: str) -> int:
# Out:
#   Cell In[53], line 15
#     torch.optim.Adam(  , self.lr )
#                        ^
# SyntaxError: invalid syntax

# %%
classifier = WordEmbeddingClassifier(
    voc_size=tokenizer.num_words,
    n_classes=2,
    d_embed=2,
    tokenizer=tokenizer,
    lr=0.01,
    n_epochs=10,
)

classifier.fit(X_train.tolist(), y_train)

print(classifier.evaluate(X_test, y_test))

# %%
# Plot the embedding matrix of a review

text = "a very bad movie i hated it."
tokens = tokenizer.encode(text)
tokens = torch.tensor([t for t in tokens if t != -1])  # Ignore invalid tokens

with torch.no_grad():
    embedded = classifier.embedding(tokens)  # Shape: (seq_len, d_embed)

plt.figure(figsize=(6, 6))
plt.imshow(embedded.T, cmap="viridis", aspect="auto")
plt.xticks(
    range(len(tokens)), [tokenizer.id_to_token[t.item()] for t in tokens], rotation=45
)
plt.ylabel("Embedding dimension")

plt.colorbar(label="Embedding value")

# %% [markdown]
# ## Word embeddings in practice
#
# - Word embeddings can be very powerful but costly to learn.
# - An innovative idea was to pre-train word embeddings on a large corpus.
# - This is the idea from the paper "Distributed Representations of Words and Phrases and their Compositionality" by Mikolov et al. (2013), which introduced the Word2Vec model.
# -
# ### Word2Vec
# - Word2Vec is a contrastive learning model.
# - Key Idea: Words with similar contexts (neighboring words) have similar vector representations.

# %% [markdown]
# ## Word2Vec: Key Ideas with Math
#
# 1. **Select a Word and Context**
#    - Randomly sample a word $w$ from a document.
#    - Define its **positive context** as the words within a window of size $R$ around $w$, excluding $w$ itself:
#      $$
#      \mathcal{C}_{\text{pos}} = [w_{i-R}, \dots, w_{i-1}, w_{i+1}, \dots, w_{i+R}].
#      $$
#
# 2. **Negative Examples**
#    - To balance the training, introduce **negative examples** by sampling $2KR$ random words from the vocabulary $\mathcal{V}$:
#      $$
#      \mathcal{C}_{\text{neg}} = \{c_1, \dots, c_{2KR}\}, \quad c_j \in \mathcal{V}.
#      $$
#
# 3. **Embedding Words**
#    - Represent the target word $w$ as a vector $\mathbf{v}_w \in \mathbb{R}^d$ using an embeddings table $\mathcal{E}_w$.
#    - Similarly, map each word in $\mathcal{C}_{\text{pos}}$ and $\mathcal{C}_{\text{neg}}$ to vectors:
#      $$
#      \mathbf{v}_{\mathcal{C}_{\text{pos}}} \in \mathbb{R}^{2R \times d}, \quad \mathbf{v}_{\mathcal{C}_{\text{neg}}} \in \mathbb{R}^{2KR \times d}.
#      $$
#
# 4. **Compute Similarity**
#    - For each context word $c$ in $\mathcal{C}_{\text{pos}} \cup \mathcal{C}_{\text{neg}}$, compute the similarity with $w$ using the dot product:
#      $$
#      s = \mathbf{v}_c \cdot \mathbf{v}_w.
#      $$
#    - Train the model to maximize the similarity between $w$ and the positive context words, and minimize the similarity with the negative context words.
